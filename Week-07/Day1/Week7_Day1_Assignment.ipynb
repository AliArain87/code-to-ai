# %% [markdown]
# # Week 7 · Day 1 — Assignment: Tell Me About Tips
#
# **Complete this before the next class. Push your finished notebook to GitHub and
# post the repo link in the group.**
#
# For the assignment you will use a **different** dataset — the `tips` dataset that
# comes built into Seaborn. It records restaurant bills, tips, and details about
# each table. No download needed.
#
# **Rules:**
# - Every chart must have a **title**, an **x-label**, and a **y-label**.
# - Use Matplotlib or Seaborn — your choice.
# - Write short answers in the markdown/comment cells where asked.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

tips = sns.load_dataset("tips")
print("Shape:", tips.shape)
tips.head()

# %% [markdown]
# The columns are: `total_bill` (the bill in dollars), `tip` (the tip in dollars),
# `sex`, `smoker`, `day`, `time` (Lunch or Dinner), and `size` (number of people at the table).

# %% [markdown]
# ## Question 1 — Distribution (histogram)
#
# Make a histogram of `total_bill`. Use about 20 bins.
#
# Then answer in the cell below: **Around what value do most bills fall?**

# %%
# Your chart here

# %% [markdown]
# *Your answer:*

# %% [markdown]
# ## Question 2 — Relationship (scatter)
#
# Make a scatter plot of `total_bill` (x) vs `tip` (y).
# Colour the dots by `time` (Lunch vs Dinner) using Seaborn's `hue`.
#
# Then answer: **As the bill goes up, does the tip usually go up too?**

# %%
# Your chart here

# %% [markdown]
# *Your answer:*

# %% [markdown]
# ## Question 3 — Comparison (bar)
#
# Compare the **average tip** for each `day`.
#
# *Hint:* group by `day` and take the mean of `tip`, or let `sns.barplot` do it
# for you with `x="day"`, `y="tip"`.
#
# Then answer: **Which day has the highest average tip?**

# %%
# Your chart here

# %% [markdown]
# *Your answer:*

# %% [markdown]
# ## Question 4 — Your own question
#
# Pick any two columns and make **one** chart that answers a question *you* find
# interesting (for example: do smokers tip differently? do bigger tables spend more?).
#
# Write your question as a comment, make the chart, and write your finding below.

# %%
# My question: 
# Your chart here

# %% [markdown]
# *My finding:*

# %% [markdown]
# ## Submission checklist
#
# - [ ] All four charts run without errors
# - [ ] Every chart has a title and axis labels
# - [ ] All four written answers are filled in
# - [ ] Notebook pushed to GitHub and link shared in the group
#
# Great work — you can now read data as pictures. See you next class!
