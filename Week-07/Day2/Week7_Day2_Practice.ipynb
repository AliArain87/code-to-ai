# %% [markdown]
# # Week 7 · Day 2 — Practice Lab: Story Choices & Streamlit Pieces
#
# Two skills to practice today:
#
# - **Part A:** choosing the right chart for a message, and annotating it.
# - **Part B:** writing small Streamlit scripts (saved to files) and reading them.
#
# Run the setup cell first.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

df = pd.read_csv("../Day1/data/gapminder.csv")
print("Loaded:", df.shape)

# %% [markdown]
# ## Part A — Storytelling
#
# ---

# %% [markdown]
# ### Task 1 — Match the chart to the message
#
# For each message below, decide the best chart type (line, bar, scatter, or
# histogram) and write it as a comment. Then make **one** of them for real.
#
# - Message A: "China's population grew hugely from 1952 to 2007."
# - Message B: "In 2007, richer countries tended to live longer."
# - Message C: "Asia had a wide range of life expectancies in 2007."
# - Message D: "Europe's average life expectancy is higher than Asia's."

# %%
# A -> 
# B -> 
# C -> 
# D -> 

# Now build ONE of these charts (your choice). Add title and axis labels.

# %% [markdown]
# ### Task 2 — Tell China's population story
#
# Filter to `country == "China"`. Make a **line** plot of `year` vs `pop`.
# Give it a clear title that states the message (for example,
# "China's Population More Than Doubled, 1952-2007").

# %%
# Your code here

# %% [markdown]
# ### Task 3 — Annotate the leader
#
# For the year 2007, make a scatter plot of `gdpPercap` vs `lifeExp`.
# Find the country with the **highest** `gdpPercap` and add a `plt.annotate`
# label pointing at it.
#
# *Hint:* `df_2007.loc[df_2007["gdpPercap"].idxmax()]` gives you that row.

# %%
# Your code here

# %% [markdown]
# ## Part B — Streamlit
#
# ---

# %% [markdown]
# ### Task 4 — Write your first app to a file
#
# Fill in the app code so it:
#
# 1. Shows a title: "My Gapminder App"
# 2. Writes a sentence describing the data
# 3. Shows the first 10 rows as a table (`st.dataframe`)
#
# Then save it to `my_app.py`. (We run it tomorrow — today just build the file.)

# %%
my_app = '''
import streamlit as st
import pandas as pd

# 1. add a title
# 2. add a line of text with st.write
# 3. load gapminder.csv and show the first 10 rows with st.dataframe

'''

with open("my_app.py", "w") as f:
    f.write(my_app)

print("Saved my_app.py — open it and check your code.")

# %% [markdown]
# Open `my_app.py` (double-click it in the file browser, or `print(open("my_app.py").read())`) and confirm your three pieces are there.

# %% [markdown]
# ### Task 5 — Add a chart to a Streamlit script
#
# Complete the script so it shows a bar chart of average `lifeExp` per continent
# for the year **2007**, using the `fig, ax = plt.subplots()` then `st.pyplot(fig)`
# pattern from class.

# %%
chart_app = '''
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

st.title("Continent Comparison")

df = pd.read_csv("gapminder.csv")
df_2007 = df[df["year"] == 2007]

# Build fig, ax
# Draw a seaborn barplot on ax (x=continent, y=lifeExp)
# Set the title and axis labels
# Finish with st.pyplot(fig)

'''

with open("chart_app.py", "w") as f:
    f.write(chart_app)

print("Saved chart_app.py")

# %% [markdown]
# ### Stretch task (optional)
#
# In `chart_app.py`, change the chart to a **scatter** of `gdpPercap` vs `lifeExp`
# coloured by continent (`hue`). Save it and read it back to check your edits.

# %%
# print your file back to read it
print(open("chart_app.py").read())

# %% [markdown]
# ## Wrap-up
#
# You practiced picking the right chart for a message and wrote your first
# Streamlit scripts. Tomorrow you assemble these pieces into one **live web app**
# and put it on the internet.
