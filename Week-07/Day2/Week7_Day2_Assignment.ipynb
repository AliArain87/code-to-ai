# %% [markdown]
# # Week 7 · Day 2 — Assignment: Plan Your Data Story
#
# **Complete this before the next class. Push to GitHub and share the link in the group.**
#
# Tomorrow you build and deploy a live app. A good app starts with a **plan**.
# Today you write that plan and prepare the charts it will contain.
#
# You will use the Gapminder data. Do the thinking now so tomorrow is smooth.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

df = pd.read_csv("../Day1/data/gapminder.csv")
print("Loaded:", df.shape)

# %% [markdown]
# ## Part 1 — Write your story (markdown)
#
# In the cell below, write in plain English:
#
# 1. **The big message** of your app in one sentence
#    (example: "Over 55 years, life expectancy rose almost everywhere, but the gap
#    between continents is still large.")
# 2. **Three facts** from the data that support your message.
# 3. **Who** would find this interesting and why.
#
# Double-click the cell to edit it.

# %% [markdown]
# *Your plan:*
#
# **Big message:**
#
# **Three supporting facts:**
# 1.
# 2.
# 3.
#
# **Who cares and why:**

# %% [markdown]
# ## Part 2 — Prepare chart #1 (a trend)
#
# Make a **line** chart that supports your message — a trend over time for one or
# more countries. Add a clear title and axis labels.
#
# You will reuse this chart in tomorrow's app, so make it good.

# %%
# Chart 1 (line) here

# %% [markdown]
# ## Part 3 — Prepare chart #2 (a comparison)
#
# Make a **bar** chart that compares groups (for example, average life expectancy
# per continent for a chosen year). Title and labels required.

# %%
# Chart 2 (bar) here

# %% [markdown]
# ## Part 4 — Prepare chart #3 (a relationship)
#
# Make a **scatter** chart showing a relationship (for example `gdpPercap` vs
# `lifeExp`), coloured by `continent` with `hue`. Title and labels required.

# %%
# Chart 3 (scatter) here

# %% [markdown]
# ## Part 5 — Which widget?
#
# Tomorrow your app will have interactive controls. In the cell below, write down:
#
# - One thing a user should be able to **pick from a dropdown** (`st.selectbox`) —
#   for example, a continent or a country.
# - One thing a user should be able to **slide** (`st.slider`) — for example, the year.
#
# Explain in one line how each control would change what the app shows.

# %% [markdown]
# *Your widget plan:*
#
# **Dropdown (`st.selectbox`) will control:**
#
# **Slider (`st.slider`) will control:**

# %% [markdown]
# ## Submission checklist
#
# - [ ] Story plan written (big message, 3 facts, audience)
# - [ ] Three charts built, each with title and labels
# - [ ] Widget plan written
# - [ ] Notebook pushed to GitHub and link shared in the group
#
# You now have a plan and three charts ready. Tomorrow we ship it live!
