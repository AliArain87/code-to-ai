# %% [markdown]
# # Code to AI — Week 1, Day 2 · PRACTICE 🧪
# ### Notebooks · f-strings · Variables · Data Types · Type Casting · input()
#
# **How to use this notebook:**
# - Read each section, then fill in the code cells where you see `# 👉 YOUR CODE HERE`.
# - Run a cell with **Shift + Enter**.
# - It's okay to make mistakes — that's how you learn! Ask freely. 🙌
#
# First, run the cell below to make sure your notebook works.

# %%
print("My notebook works! ✅")

# %% [markdown]
# ---
# ## Part 1 · f-strings 🎯
#
# **Reminder:** put `f` before the quotes, drop variables inside `{ }`.

# %% [markdown]
# **1.1** — Run this example first.

# %%
name = "Sara"
hobby = "painting"
print(f"Hi, I am {name} and I love {hobby}.")

# %% [markdown]
# **1.2** — Your turn. Make variables `your_name` and `your_city`, then print:
# `Hi, I am ___ from ___.` using an **f-string**.

# %%
# 👉 YOUR CODE HERE

# %% [markdown]
# **1.3** — Math inside braces. Fix the cell so it prints the total of 12 × 8 using an f-string.

# %%
# 👉 complete this line
# print(f"12 times 8 is {  }")

# %% [markdown]
# ---
# ## Part 2 · Variables 📦
#
# A variable stores a value. Names are **case-sensitive** and can't start with a number.

# %% [markdown]
# **2.1** — Create three variables: `fruit` (a string), `count` (a whole number), `price` (a decimal). Then print a sentence about them with an f-string.

# %%
# 👉 YOUR CODE HERE

# %% [markdown]
# **2.2** — Reassigning. `score` starts at 50. Change it to 80, then print the new value.

# %%
score = 50
# 👉 change score to 80 and print it

# %% [markdown]
# ---
# ## Part 3 · Data Types 🔍
#
# Use `type()` to check what kind of value something is.

# %% [markdown]
# **3.1** — Predict first, then run. Before running, **write a comment** guessing each type.

# %%
print(type("hello"))   # guess: 
print(type(42))        # guess: 
print(type(3.5))       # guess: 
print(type(False))     # guess:

# %% [markdown]
# **3.2** — The quotes trap. Why does this NOT give 30? Write your answer in a comment, then fix it so it prints 30.

# %%
x = "10"
y = "20"
print(x + y)   # this prints "1020" — why?
# 👉 fix it below so it prints 30

# %% [markdown]
# ---
# ## Part 4 · Type Casting + input() 🔄
#
# `int()`, `float()`, `str()` convert between types. `input()` **always** returns a string.

# %% [markdown]
# **4.1** — Convert and add. These are strings. Cast them and print their sum (should be 15).

# %%
a = "9"
b = "6"
# 👉 YOUR CODE HERE

# %% [markdown]
# **4.2** — Using `input()`. Ask the user for two numbers and print their sum.
# *(Tip: `input()` gives a string, so wrap it in `int(...)`.)*

# %%
# 👉 YOUR CODE HERE
# num1 = int(input("First number: "))
# num2 = ...
# print(...)

# %% [markdown]
# **4.3** — Mini challenge 🌟 Ask the user for their **name** and **birth year**, then print:
# `Hi NAME, you are about AGE years old!` (age = 2026 − birth year).

# %%
# 👉 YOUR CODE HERE

# %% [markdown]
# ---
# ### ✅ Done?
# Check you can: make a notebook, use f-strings, create variables, check types with `type()`, cast with `int/float/str`, and read `input()`.
