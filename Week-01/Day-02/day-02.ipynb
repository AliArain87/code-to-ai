# %% [markdown]
# # **Assignment task 1 - My Name**

# %% [markdown]
# ## Here I will write my name in print statement

# %% [markdown]
# ### And you can see my output in below cell

# %%
# Assignment task 1 - MY name
print("My name is Ali")
# Out:
# My name is Ali

# %% [markdown]
# ## **Variables**

# %%
print("I am Ali Hasnain")
# Out:
# I am Ali Hasnain

# %%
name = "Ali Hasnain"
print(name)
# Out:
# Ali Hasnain

# %%
print("Ali Hasnain")
# Out:
# Ali Hasnain

# %%
print("Asim")
# Out:
# Asim

# %%
x = 12
y = 5
print(x + y)
# Out:
# 17

# %%
name = "Asim"
print(name)
# Out:
# Asim

# %%
greeting = "Hello, we welcome you to this class"
name = 'Munir'
print(greeting, name)
# Out:
# Hello, we welcome you to this class Munir

# %%
a = 10
b = 20

print("a + b = ",a + b)
print("a - b = ",a - b)
print("a * b = ",a * b)
# Out:
# a + b =  30
# a - b =  -10
# a * b =  200

# %%
# a, b = 40, 50
print(a)
print(b)
# Out:
# 10
# 20

# %%
percentage = 85
print("Your percentage is: ", percentage)
# Out:
# Your percentage is:  85

# %%
1name = "Ali"
print(1name)
# Out:
#   Cell In[33], line 1
#     1name = "Ali"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "Ali"
print(name1)
# Out:
# Ali

# %%
name_1 = "Ali"
print(name_1)
# Out:
# Ali

# %%
name 1 = "Ali"
print(name 1)
# Out:
#   Cell In[36], line 1
#     name 1 = "Ali"
#          ^
# SyntaxError: invalid syntax

# %%
a, b, c = 1, 1, 1
print(a, b, c)
# Out:
# 1 1 1

# %%
a = b = c = 1
print(a, b, c)
# Out:
# 1 1 1

# %%
a = 10
b = 20
print(a + b)
# Out:
# 30

# %%
a, b = 2, 3
print(a * b)
# Out:
# 6

# %%
num1 = num2 = 23 
print("num1 = ", num1)
print("num2 = ", num2)
# Out:
# num1 =  23
# num2 =  23

# %%
# 2 
# hello
# 2.5
# Boolen True, False

# %%
is_pass = True
is_fail = False
name = "Ali"
std2 = "Asim"

print("Ali has passed: ", is_pass)
print("Asim has failed: ", is_fail)
# Out:
# Ali has passed:  True
# Asim has failed:  False

# %%
number1 = 10
number2 = 25.5

# %%
print("The type of number 1 is ", type(number1))
# Out:
# The type of number 1 is  <class 'int'>

# %%
print("The type of number 2 is ", type(number2))
# Out:
# The type of number 2 is  <class 'float'>

# %%
name = "Ali Hasnain"

# %%
print("The type of name is ", type(name))
# Out:
# The type of name is  <class 'str'>

# %% [markdown]
# ### Boolen Data type
# - True
# - False

# %%
is_true = True
is_false = False
is_check = "Notcheck"

# %%
print("Is true is", type(is_true))
print("Is false is", type(is_false))
# Out:
# Is true is <class 'bool'>
# Is false is <class 'bool'>

# %%
print("is check is", type(is_check))
# Out:
# is check is <class 'str'>

# %% [markdown]
# ### **Math Equations**
# - e = mc^2

# %%
m = 24 # m contains 10
c = 23 # c contains 2
c = c ** 2 # c contains the value of c raised to the power of 2
e = m * c # e contains the value of m multiplied by c
print("e = mc^2 =", e)
# Out:
# e = mc^2 = 12696

# %% [markdown]
# ### f string in formating

# %%
print("The value of m is", m)
# Out:
# The value of m is 24

# %%
print(f"The value of m is {m}")
# Out:
# The value of m is 24

# %%
print(f"m = {m}, c = {c}, e = {e}")
# Out:
# m = 24, c = 529, e = 12696

# %%
print(f"The Sum of {m} and {c} is {m+c}")
# Out:
# The Sum of m and c is 553

# %%
print(f"The Sum of {m} and {c} is {m+c}")
# Out:
# The Sum of 24 and 529 is 553

# %% [markdown]
# ## **TypeCaste ya TYpe conversion**

# %% [markdown]
# #### **Int to float**

# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
x = 10
print(f"The value of {x} before typecasting is {x}")
print(f"And the type of {x} before typecasting is {type(x)}")
x = float(x)
print(f"The value of {x} after typecasting is {x}")
print(type(x))
# Out:
# The value of 10 before typecasting is 10
# And the type of 10 before typecasting is <class 'int'>
# The value of 10.0 after typecasting is 10.0
# <class 'float'>

# %% [markdown]
# ### **Float to Int**

# %%
b = 24.9
print(f"b = {b} and type of b is {type(b)}")
# Out:
# b = 24.9 and type of b is <class 'float'>

# %%
b = int(b)
print(f"b = {b} and type of b is {type(b)}")
# Out:
# b = 24 and type of b is <class 'int'>

# %% [markdown]
# ### **String convertion**
# - Str to int (Not valid)

# %%
name = "Ali Hasnain"
print(f"Name = {name} and type of name is {type(name)}")
# Out:
# Name = Ali Hasnain and type of name is <class 'str'>

# %%
name = int(name)
print(f"Name = {name} and type of name is {type(name)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 name = int(name)
#       2 print(f"Name = {name} and type of name is {type(name)}")
#
# ValueError: invalid literal for int() with base 10: 'Ali Hasnain'

# %% [markdown]
# ### **Int to Str**
# - Valid

# %%
b = 20
print(f"b = {b} and type of b is {type(b)}")
# Out:
# b = 20 and type of b is <class 'int'>

# %%
b = str(b)
print(f"b = {b} and type of b is {type(b)}")
# Out:
# b = 20 and type of b is <class 'str'>

# %%
c = b + " is a string now"
print(c)
# Out:
# 20 is a string now

# %%
test = 12 
c = test + 23
print(c)
# Out:
# 35

# %%
print(2+3)
# Out:
# 5

# %%
print("2+3")
# Out:
# 2+3

# %% [markdown]
# ### **First cell in markdown**

# %%
print(f" This is my Second cell")
# Out:
#  This is my Second cell
