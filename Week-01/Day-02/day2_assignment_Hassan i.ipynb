# %% [markdown]
# # Code to AI — Week 1, Day 2 · ASSIGNMENT 📝
# ### Due: **before the next class**
#
# **Submit:** push this notebook to a GitHub repo and post the repo link in the WhatsApp group.
#
# **Topics tested:** notebooks · f-strings · variables · data types · type casting
#
# **Rules:**
# - Only use what we learned today (no `if`/loops yet — that's Week 3 😉).
# - Write clean f-strings. Add a short comment on each task explaining what it does.
# - Run every cell before submitting (use **Restart & Run All**).

# %% [markdown]
# ---
# ## Task 1 — About You (f-strings + variables) ⭐
# Create variables for your `name`, `city`, and `favorite_subject`.
# Print **one** nicely formatted sentence using an **f-string** that uses all three.

# %%
name = "muhammad hasan"
city = "khanpur"
favourite_subjact = "mathematics"
print("F,my name is {muhammad hassan},i am from {khanpur},and my favourite subject is {mathematices}")
# Out:
# F,my name is {muhammad hassan},i am from {khanpur},and my favourite subject is {mathematices}

# %%
name = "muhammad hasan"
city = "khanpur"
favourite_subjact = "mathematics"
print(f"my name is {name},i am from {city},and my favourite subject is {favourite_subjact}")
# Out:
# my name is muhammad hasan,i am from khanpur,and my favourite subject is mathematics

# %% [markdown]
# ## Task 2 — Type Detective (data types) ⭐
# For each value below, print its type using `type()`:
# `"Python"`, `2026`, `19.5`, `True`.

# %%
print("type(pyton)")#string
print("type(2026)")#integer
print("type(19.5)")#float
print("type(true)")#bool
# Out:
# type(pyton)
# type(2026)
# type(19.5)
# type(true)

# %%
print(type("Python"))
print(f"The type of python is type() {type("Python")}")
# Out:
# <class 'str'>
# The type of python is type() <class 'str'>

# %% [markdown]
# ## Task 3 — Fix the Bug 🐞
# The code below is meant to add two numbers and print **35**, but it doesn't.
# Explain the problem in a comment, then fix it.

# %%
a = "20"
b = "15"
print(a + b)   # currently prints "2015"
# 👉 explain + fix below
#is ma hum aina add bi karnay ya add nai hoa ga ya dona str ha uar do conas na tota jis ki waja sa aad nai ho akta is 2015 as it is ata ha
# Out:
# 2015

# %% [markdown]
# ---
# ### 🌟 Bonus (optional)
# Add a `:,` inside a brace to put commas in big numbers, e.g. `{big_number:,}` → `140,000,000`.
# Try it on your breaths line!

# %%
numb = 256.34356
print(f"{numb:.2f}")
# Out:
# 256.34

# %% [markdown]
# ---
# ### ✅ Before you submit
# - [ ] Every cell runs without errors (Restart & Run All)
# - [ ] Each task has a short comment
# - [ ] Submit Notebook in WhatsApp group
#
# Great work — see you next class! 💪🚀
