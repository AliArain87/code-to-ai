# %% [markdown]
# # Week 8 · Day 1 — Assignment
# # Your First ML Model — Graded 🍷
#
# **Goal:** prove you can run the full 5-step ML recipe on a **new dataset you haven't seen in class**.
#
# This notebook is **portfolio quality** — it goes to your public GitHub. Write clean code and clear markdown. A US recruiter or professor may read it.
#
# **Dataset:** the **Wine** dataset built into scikit-learn. Each row is a wine; the target is which of 3 cultivars (wine types) it came from, based on chemical measurements.
#
# **Marks: 10 total**
# - Load & explore (2)
# - X / y split (1)
# - Train / test split (2)
# - Train model (1)
# - Predict + accuracy (2)
# - Written reflection markdown (2)
#
# > Reminder: keep everything in **English**, add short comments, and run every cell before you push.

# %% [markdown]
# ## Part 0 — Load the data (given)
#
# Run this cell as-is. It loads the Wine dataset into a clean DataFrame for you.

# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load into a DataFrame
data = load_wine(as_frame=True)
wine = data.frame          # features + a 'target' column (0, 1, 2 = wine type)

wine.head()

# %% [markdown]
# ## Part 1 — Explore (2 marks)
#
# Print the **shape** of the dataset, and use `value_counts()` on the `target` column to see how many wines of each type there are.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 2 — Split into X and y (1 mark)
#
# - `X` = every column **except** `target`  *(hint: `wine.drop(columns="target")`)*
# - `y` = the `target` column

# %%
X = # YOUR CODE HERE
y = # YOUR CODE HERE

print("X shape:", X.shape)
print("y shape:", y.shape)

# %% [markdown]
# ## Part 3 — Train / Test split (2 marks)
#
# Hold out **20%** for testing. Use `random_state=42`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 4 — Train a KNN model (1 mark)
#
# Use `n_neighbors=5`. Fit it on the training data.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 5 — Predict and score (2 marks)
#
# Predict on the test set and print the accuracy as a percentage.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part 6 — Reflection (2 marks) ✍️
#
# Double-click this cell and answer in your own words (3–5 sentences):
#
# 1. What were the **features** and what was the **target** in this problem?
# 2. What accuracy did your model reach?
# 3. In one sentence: why do we keep a separate **test set** instead of scoring on the training data?
#
# *Your answer here:*
#
#
#
# ---
# **Submit:** push this notebook to a new GitHub repo (e.g. `code-to-ai-first-ml-model`) and post the repo link in the WhatsApp group. 🚀
