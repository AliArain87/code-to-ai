# %% [markdown]
# # Week 4 · Day 2 — Practice Lab: Statistics & Filtering
# ### Code to AI — Python & Data Science
#
# ---
# Practice today's tools: aggregations, `axis`, boolean masks, `np.where`, and reshaping.
# Write your code under each `# YOUR CODE HERE`. Run every cell as you go. 💪

# %%
import numpy as np

# %% [markdown]
# ## Exercise 1 — Basic statistics
# Here are the daily temperatures for a week. Print the **mean**, **median**, **min**, **max**, and **standard deviation**.

# %%
temps = np.array([30, 33, 29, 35, 27, 36, 31])

# YOUR CODE HERE

# %% [markdown]
# ## Exercise 2 — Spread check
# Two classes scored these marks. Both have a similar average — but which class is more **consistent** (smaller std)? Print the mean and std of each and decide.

# %%
class_a = np.array([70, 72, 68, 71, 69])
class_b = np.array([40, 95, 60, 90, 65])

# YOUR CODE HERE

# %% [markdown]
# ## Exercise 3 — The axis idea
# Given this table of 3 students × 3 tests, find:
# 1. Each student's average (across their row).
# 2. Each test's average (down the column).

# %%
marks = np.array([[80, 70, 90],
                  [60, 75, 85],
                  [95, 80, 70]])

# YOUR CODE HERE

# %% [markdown]
# ## Exercise 4 — Boolean masks
# From the sales array below:
# 1. Show only the sales above 500.
# 2. Count how many days had sales above 500.
# 3. Show only the sales below 200.

# %%
sales = np.array([320, 550, 180, 700, 640, 150, 480])

# YOUR CODE HERE

# %% [markdown]
# ## Exercise 5 — np.where labeling
# Using the same sales array, create a label array that says `"GOOD"` when sales are 500 or above, and `"LOW"` otherwise. Print it.

# %%
sales = np.array([320, 550, 180, 700, 640, 150, 480])

# YOUR CODE HERE

# %% [markdown]
# ## Exercise 6 — Reshaping
# 1. Create an array of numbers from 1 to 12 using `np.arange`.
# 2. Reshape it into 4 rows × 3 columns.
# 3. Print the reshaped grid, then flatten it back to 1D.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 🌟 Stretch (optional) — Above average
# Given the array below:
# 1. Compute the average.
# 2. Use a boolean mask to show only the values **above** the average.
# 3. Count how many values are above average.

# %%
data = np.array([12, 45, 33, 8, 27, 50, 19, 40])

# YOUR CODE HERE

# %% [markdown]
# ### Well done! ✅
# You can now summarize and filter data — the heart of data analysis.
# Day 3: we do this on a **real CSV** and ship it to GitHub. 🚀
