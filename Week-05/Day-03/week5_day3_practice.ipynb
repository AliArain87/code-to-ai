# %% [markdown]
# # Week 5 — Day 3: Practice Lab
# ### Build Your Own Explorer — Guided
#
# ---
#
# **How to use this notebook**
#
# In class we built the Titanic Data Explorer together. Here you build the **same kind of
# explorer** on a different dataset — but with guidance and hints.
#
# The assignment removes the hints. This lab is the bridge.
#
# **Dataset:** `planets` — real data on exoplanets discovered outside our solar system.
# Nobody in class has seen it before. That is the point.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

planets = sns.load_dataset("planets")
print("Loaded:", planets.shape)
planets.head()

# %% [markdown]
# ### About this dataset
#
# Each row is one **exoplanet** — a planet orbiting a star other than our Sun.
#
# | Column | Meaning |
# |--------|---------|
# | `method` | How the planet was detected |
# | `number` | Number of planets known in that star system |
# | `orbital_period` | Days for one orbit around its star |
# | `mass` | Planet mass (in Jupiter masses) |
# | `distance` | Distance from Earth (in parsecs) |
# | `year` | Year of discovery |

# %% [markdown]
# ## Part A — Inspect
#
# ### Task A1
# Run the full 5-command ritual on `planets`. One cell per step, so the output is readable.
#
# **Hint:** `.head()`, `.shape`, `.info()`, `.describe()`, `.isna().sum()`

# %%
# A1a — head
# YOUR CODE HERE

# %%
# A1b — shape, printed as a sentence
# YOUR CODE HERE

# %%
# A1c — info
# YOUR CODE HERE

# %%
# A1d — describe
# YOUR CODE HERE

# %%
# A1e — missing values
# YOUR CODE HERE

# %% [markdown]
# ### Task A2
# Which column has the most missing values, and how many? Write it below.
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ## Part B — Frame your questions
#
# Before writing more code, write **five questions** you want to answer about this dataset.
#
# A good question can be answered with a number. A bad question is vague.
#
# - ✅ *"Which detection method has found the most planets?"*
# - ❌ *"What are planets like?"*
#
# **Hint:** look at the column list. Each column suggests a question.
#
# **Your five questions:**
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## Part C — Answer them
#
# ### Task C1 — Which `method` has discovered the most planets?
# **Hint:** `value_counts()`

# %%
# YOUR CODE HERE

# %% [markdown]
# **Insight:** *(one sentence with a number)*

# %% [markdown]
# ### Task C2 — In which `year` were the most planets discovered?
# **Hint:** `value_counts()` again, and look at the top.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Insight:**

# %% [markdown]
# ### Task C3 — What is the average `orbital_period` for each detection `method`?
# **Hint:** `groupby`

# %%
# YOUR CODE HERE

# %% [markdown]
# **Insight:**

# %% [markdown]
# ### Task C4 — Show the 5 planets closest to Earth.
# Display `method`, `distance`, `year`.
# **Hint:** `.nsmallest()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C5 — Show the 5 most massive planets.
# **Hint:** `.nlargest()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C6 — How many planets were discovered after 2010?
# **Hint:** filtering

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C7 — How many planets were found by the `Radial Velocity` method **and** discovered before 2005?
# **Hint:** two conditions, each in its own brackets, joined with `&`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C8 — Using `.between()`, how many planets were discovered between 2005 and 2010 inclusive?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C9 — Using `.agg()`, for each `method` show:
# the count, the average `distance`, and the average `year` of discovery.
#
# **Hint:**
# ```python
# df.groupby("method").agg({"distance": "mean", "year": "mean"})
# ```
# You will need to add the count too.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Insight:**

# %% [markdown]
# ### Task C10 — Build a derived column
# Make a copy called `df`. Add a column `orbital_years` = `orbital_period` / 365.
#
# Then show the 5 planets with the longest orbit in years.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C11 — Handle the missing data honestly
# Create `known_mass` — only the rows where `mass` is not missing.
# Print how many rows that leaves, and what percentage of the full dataset that is.
#
# **Hint:** `.notna()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C12 — Using `known_mass` only, find the average `mass` per `method`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part D — One chart
#
# ### Task D1
# Make a bar chart of the number of planets found by each `method`.
#
# **Hint:**
# ```python
# df["method"].value_counts().plot(kind="bar", title="...", ylabel="...")
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task D2
# Make a bar chart of the number of planets discovered per `year`.
#
# **Hint:** `value_counts()` sorts by count by default. You want it sorted by year —
# try `.sort_index()` before `.plot()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# **What does the shape of that chart tell you? One sentence.**
#
# *(write here)*

# %% [markdown]
# ## Part E — Write it up
#
# ### Task E1
# Write **three findings** about exoplanets, each one sentence with a real number from
# your work above.
#
# **Finding 1:**
#
# **Finding 2:**
#
# **Finding 3:**
#
# ### Task E2
# Write **one limitation** of this dataset.
#
# **Limitation:**
#
# ### Task E3
# Write the **first two lines** of a README for this project — the title and a one-sentence
# description that would make someone want to click.
#
# ```markdown
# # (your title)
#
# (your one-sentence description)
# ```

# %% [markdown]
# ## Stretch tasks (optional)
#
# ### Stretch 1
# For each `method`, find the **earliest** and **latest** discovery year.
# Which method is the newest?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Stretch 2
# Among planets discovered after 2010, which `method` dominates?
# Compare it to planets discovered before 2000. Has the technology changed?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Stretch 3
# Create three distance bands using filtering (close / medium / far — you choose the cutoffs)
# and report how many planets are in each.
#
# Then say in one sentence why your cutoffs are reasonable. There is no right answer —
# but you must be able to defend your choice. That is analysis.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Done!
#
# Notice what just happened: you opened a dataset you had never seen, and within an hour
# you knew more about it than most people ever will.
#
# The dataset changed. Your process did not. **That** is the skill.
#
# **Now:** do it once more, with no hints, in the assignment. 🚀
