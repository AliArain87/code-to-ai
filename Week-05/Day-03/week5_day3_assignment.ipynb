# %% [markdown]
# # Week 5 — Day 3: Assignment
# # 🚀 BUILD & SHIP PROJECT
# ## Your Own Data Explorer
#
# ### Code to AI — Python & Data Science (from Zero to Portfolio)
#
# ---
#
# **Your name:**
# **Date:**
# **Repo link:**
#
# ---
#
# ## This one is different
#
# Every assignment so far has told you what to compute. This one does not.
#
# You are given a dataset and a blank notebook. **You** decide the questions.
# **You** decide what is worth reporting. **You** write the story.
#
# This is the first assignment that goes on your portfolio as a real project.
# A US recruiter or admissions reviewer may actually read it. Build it like they will.
#
# ## Your dataset: `tips`
#
# 244 restaurant bills. Each row: the total bill, the tip, the customer's sex, whether
# they smoked, the day, the time (Lunch or Dinner), and the party size.
#
# ```python
# tips = sns.load_dataset("tips")
# ```
#
# ## Your mission
#
# > **Build a Data Explorer that answers: what drives tipping at this restaurant?**
#
# Five questions of your own choosing. Answered with code. Written up in plain English.
# Shipped to GitHub with a README that makes someone want to read it.
#
# ## What to submit
# 1. This completed notebook
# 2. A **public GitHub repo** containing it
# 3. A `README.md` following the Problem → Approach → Result structure
# 4. The repo link posted in the WhatsApp group
#
# **Deadline:** before the next class.
#
# ## Rules
# - Week 5 tools only (Day 1 + Day 2 + one `.plot()`)
# - Every number computed by code, never typed by hand
# - English only — this repo is public and US-facing
# - Findings must be **sentences with numbers**, not code output pasted in

# %%
# Setup — run this first
import pandas as pd
import numpy as np
import seaborn as sns

tips = sns.load_dataset("tips")
print("Loaded", tips.shape[0], "bills.")

# %% [markdown]
# ---
# # PART 1 — INSPECT (10 points)
# ---
#
# Run the 5-command ritual. Use one cell per command.

# %%
# YOUR CODE HERE — head

# %%
# YOUR CODE HERE — shape, as a sentence

# %%
# YOUR CODE HERE — info

# %%
# YOUR CODE HERE — describe

# %%
# YOUR CODE HERE — missing values

# %% [markdown]
# ### What did the inspection tell you?
#
# Write 2 to 3 sentences describing this dataset to someone who has never seen it.
# Mention the size, the columns, and whether anything is missing.
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ---
# # PART 2 — FRAME YOUR QUESTIONS (15 points)
# ---
#
# Write **five questions** you will answer. This is the most important cell in the notebook —
# everything below depends on it.
#
# Rules for a good question:
# - It can be answered with a **number**
# - It is about the **restaurant owner's interests**, not yours
# - Together, your five should tell one coherent story
#
# Write them **before** you write any more code. Do not skip ahead.
#
# **Q1:**
#
# **Q2:**
#
# **Q3:**
#
# **Q4:**
#
# **Q5:**
#
# ### Why these five?
# In one or two sentences, explain what story you are trying to tell.
#
# *(write here)*

# %% [markdown]
# ---
# # PART 3 — BUILD YOUR DERIVED COLUMN (10 points)
# ---
#
# Raw `tip` is a bad measure — it hides the bill size. Build something better.
#
# Make a copy called `df` and add at least one derived column of your own design.
# (`tip_percent` is the obvious one. You may add more if you want.)
#
# Then explain **why** your column is more useful than the raw data.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Why this column is more useful:**
#
# *(write here)*

# %% [markdown]
# ---
# # PART 4 — ANSWER YOUR QUESTIONS (30 points)
# ---
#
# One section per question. For each:
# 1. A markdown cell restating the question
# 2. Code that answers it
# 3. A **💡 Insight** cell — one sentence, with a number, in plain English
#
# Add more cells if you need them.
#
# ---
#
# ## Q1: *(restate your question here)*

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 💡 Insight 1
#
# *(write here)*

# %% [markdown]
# ## Q2: *(restate your question here)*

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 💡 Insight 2
#
# *(write here)*

# %% [markdown]
# ## Q3: *(restate your question here)*

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 💡 Insight 3
#
# *(write here)*

# %% [markdown]
# ## Q4: *(restate your question here)*

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 💡 Insight 4
#
# *(write here)*

# %% [markdown]
# ## Q5: *(restate your question here)*

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 💡 Insight 5
#
# *(write here)*

# %% [markdown]
# ---
# # PART 5 — REQUIRED TECHNIQUES (10 points)
# ---
#
# Somewhere in Part 4 you must have used **all** of these. If you missed any, use them here.
#
# Tick each one and paste the line of code where you used it.
#
# - [ ] Boolean filtering with **two or more** conditions (`&` or `|`)
# - [ ] `.isin()` **or** `.between()`
# - [ ] `groupby()` on **one** column
# - [ ] `groupby()` on **two** columns
# - [ ] `.agg()` with more than one summary
# - [ ] `.nlargest()` **or** `.nsmallest()`
# - [ ] A derived column
#
# Use the cell below for anything you still need.

# %%
# YOUR CODE HERE — any techniques you still need to demonstrate

# %% [markdown]
# ---
# # PART 6 — ONE CHART (5 points)
# ---
#
# Make **one** bar chart showing your most important finding.
#
# One chart. Not five. Choose the one that makes your strongest point.
# Give it a title and an axis label.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Why this chart and not another?**
#
# *(write here)*

# %% [markdown]
# ---
# # PART 7 — THE REPORT (20 points)
# ---
#
# This is the part that matters. Write for the restaurant owner. She is smart, busy,
# and does not code. No column names. No jargon. No code.
#
# ## Summary
# Two or three sentences: what did you investigate, and what did you find overall?
#
# *(write here)*
#
# ## Three key findings
# Each one sentence, each with a real number from your analysis.
#
# **1.**
#
# **2.**
#
# **3.**
#
# ## One recommendation
# Based on your findings, what is one concrete thing she should actually do differently?
#
# *(write here)*
#
# ## One limitation
# What can this data **not** tell her? Be honest. This is what separates an analyst
# from someone who just runs code.
#
# *(write here)*

# %% [markdown]
# ---
# # PART 8 — SHIP IT
# ---
#
# An unpushed project does not exist. Ship it.
#
# ### 1. Create a public repo
# Suggested name: `restaurant-tipping-explorer`
#
# ### 2. Structure it
#
# ```
# restaurant-tipping-explorer/
# ├── README.md
# ├── tipping_explorer.ipynb
# └── .gitignore
# ```
#
# ### 3. Write the README
#
# Fill in this template. **Do not** leave the brackets in.
#
# ```markdown
# # Restaurant Tipping Explorer
#
# [One sentence that makes someone want to read this.]
#
# ## The question
# [What were you trying to find out, and why does it matter?]
#
# ## The data
# 244 restaurant bills with total bill, tip, customer sex, smoker status, day,
# time, and party size. Loaded via `seaborn.load_dataset("tips")`.
#
# ## Approach
# - [What you built and why]
# - [How you sliced the data]
# - [What you compared]
#
# ## Key findings
# 1. [Finding with a number]
# 2. [Finding with a number]
# 3. [Finding with a number]
#
# ## Recommendation
# [Your one concrete recommendation]
#
# ## Limitation
# [What this data cannot tell us]
#
# ## Tools
# Python · Pandas · Seaborn · Google Colab
#
# ## How to run
# Open `tipping_explorer.ipynb` in Google Colab and run all cells.
# ```
#
# ### 4. Push it
#
# ```bash
# git init
# git add .
# git commit -m "Add restaurant tipping analysis with Pandas"
# git branch -M main
# git remote add origin https://github.com/YOUR-USERNAME/restaurant-tipping-explorer.git
# git push -u origin main
# ```
#
# ### 5. Post the link in the WhatsApp group
#
# ### Before you post — check your repo
# - [ ] The README is filled in (no `[brackets]` left)
# - [ ] The notebook runs top to bottom with no errors
# - [ ] All outputs are visible (run all cells before saving)
# - [ ] Every insight is a sentence, not pasted code output
# - [ ] Everything is in English
# - [ ] The commit message says what you did

# %% [markdown]
# ---
#
# ## Marking guide (100 points)
#
# | Part | What | Points |
# |------|------|--------|
# | 1 | Inspect | 10 |
# | 2 | Frame your questions | 15 |
# | 3 | Derived column | 10 |
# | 4 | Answer your questions | 30 |
# | 5 | Required techniques | 10 |
# | 6 | One chart | 5 |
# | 7 | The report | 20 |
# | 8 | Ship it | *required* |
#
# **No repo = not submitted.** The point of this course is the portfolio.
#
# ---
#
# ## A note from Ali
#
# This is the first project on your GitHub that a stranger might judge you on.
#
# Here is what I want you to understand: the code in Part 4 is the **easy** part.
# Any of you can write `groupby`. What almost nobody can do — including people with
# degrees — is Part 7. Turning a number into a sentence that helps someone decide something.
#
# That is the job. That is what gets you hired.
#
# So do not rush Part 7. It is 5 minutes of writing that is worth more than the other
# 70 minutes combined.
#
# Ship it. Post the link. I want to see all of them. 🚀
