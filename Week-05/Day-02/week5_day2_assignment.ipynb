# %% [markdown]
# # Week 5 — Day 2: Assignment
# ## The Restaurant Tipping Investigation
#
# ### Code to AI — Python & Data Science (from Zero to Portfolio)
#
# ---
#
# **Your name:**
# **Date:**
#
# ---
#
# ## The scenario
#
# You have been hired by a restaurant owner. She has 244 bills from her restaurant and
# one question:
#
# > **"Who tips well, and when? I want to know where my money actually comes from."**
#
# Your job is to answer her with data — not opinions.
#
# ## The dataset
# `tips` — one row per bill, with the total bill, tip amount, the customer's sex,
# whether they smoked, the day, the time (Lunch/Dinner), and the party size.
#
# ## What to submit
# 1. Complete every task below.
# 2. Push this notebook to a **public GitHub repo**.
# 3. Add a `README.md` (template at the bottom).
# 4. Post the repo link in the WhatsApp group.
#
# **Deadline:** before the next class.
#
# ## Rules
# - Use Day 1 + Day 2 tools only.
# - Every number must be **computed**, never typed by hand.
# - Write your conclusions in **plain English** in the markdown cells.
# - Your client is not a programmer. Write for her, not for a computer.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

tips = sns.load_dataset("tips")
print("Loaded", tips.shape[0], "bills.")
tips.head()

# %% [markdown]
# ## Task 1 — Get to know the data (10 points)
#
# Run the 5-command ritual. One cell per step.
#
# ### 1a. `.head()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1b. `.shape` as a sentence

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1c. `.info()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1d. `.describe()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1e. `.isna().sum()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 2 — Build the key measure (10 points)
#
# The raw `tip` column is misleading — a $10 tip on a $100 bill is stingy, but a $10 tip
# on a $20 bill is generous. We need a **percentage**.
#
# ### 2a. Make a copy of `tips` called `df`, then add a column `tip_percent`:
# `tip_percent = (tip / total_bill) * 100`
#
# Show `total_bill`, `tip`, `tip_percent` for the first 5 rows.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 2b. Print the average, minimum, and maximum `tip_percent`, each rounded to 2 decimals.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 2c. In one sentence, explain to the restaurant owner why `tip_percent` is a
# better measure than `tip` on its own.
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ## Task 3 — Filtering questions (15 points)
#
# Answer each with code.
#
# ### 3a. How many bills were over $30?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3b. How many bills were on a **Sunday** with a party of **4 or more**?
# Use two conditions.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3c. Using `.isin()`, how many bills were on the weekend (`Sat` or `Sun`)?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3d. Using `.between()`, how many bills were between $15 and $25 inclusive?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3e. Using `~`, how many bills were **not** from smokers?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 4 — The five client questions (30 points)
#
# Use `groupby` for each. Then write a **one-sentence answer in plain English** below it.
#
# ### Q1: Does the day of the week affect tip percentage?

# %%
# YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# *(write here)*

# %% [markdown]
# ### Q2: Do Lunch or Dinner customers tip better?

# %%
# YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# *(write here)*

# %% [markdown]
# ### Q3: Does party `size` affect tip percentage?

# %%
# YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# *(write here)*

# %% [markdown]
# ### Q4: Do smokers tip differently from non-smokers?

# %%
# YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# *(write here)*

# %% [markdown]
# ### Q5: Which combination of `day` **and** `time` brings the highest average `total_bill`?
# Group by two columns.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Answer:**
#
# *(write here)*

# %% [markdown]
# ## Task 5 — The top and bottom (10 points)
#
# ### 5a. Show the 5 bills with the highest `tip_percent`.
# Display `total_bill`, `tip`, `tip_percent`, `size`, `day`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 5b. Show the 5 bills with the **lowest** `tip_percent`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 5c. Look at both tables. Is there a pattern in the `total_bill` of the best tippers
# versus the worst? Write two sentences.
#
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ## Task 6 — Use `.agg()` (10 points)
#
# For each `day`, produce a single table showing:
# - the number of bills (`count`)
# - the average `total_bill`
# - the total `total_bill` (sum) — this is the day's revenue
# - the average `tip_percent`
#
# Hint: use `.agg()` with a dictionary.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Which day makes the most total revenue?**
#
# *(write here)*

# %% [markdown]
# ## Task 7 — The report to your client (15 points)
#
# Write a short report for the restaurant owner. She is smart but not technical.
# No code, no jargon, no column names. Just findings and advice.
#
# ### Three findings
# Each must be one sentence with a real number from your analysis.
#
# **Finding 1:**
#
# **Finding 2:**
#
# **Finding 3:**
#
# ### One recommendation
# Based on your findings, what is **one concrete thing** she should do?
# One or two sentences.
#
# **Recommendation:**
#
# ### One honest limitation
# What is one thing this data **cannot** tell her? Every good analyst says this out loud.
#
# **Limitation:**

# %% [markdown]
# ## Task 8 — Ship it (empty repo = no marks)
#
# 1. Create a **public** GitHub repo, e.g. `tips-analysis-pandas`.
# 2. Upload this completed notebook.
# 3. Add a `README.md` using the template below.
# 4. Post the link in the WhatsApp group.
#
# ### README template
#
# ```markdown
# # Restaurant Tipping Analysis
#
# An analysis of 244 restaurant bills to find out who tips well, and when.
# Part of the Code to AI course (Week 5, Day 2).
#
# ## The question
# Which customers, days, and times produce the best tips — and the most revenue?
#
# ## The data
# The `tips` dataset: 244 bills with total bill, tip, sex, smoker, day, time, party size.
# Loaded via `seaborn.load_dataset("tips")`.
#
# ## Approach
# - Built a `tip_percent` column, since raw tip amount hides bill size
# - Filtered and grouped by day, time, party size, and smoker status
# - Compared average tip percentage and total revenue across groups
#
# ## Key findings
# 1. (your finding 1)
# 2. (your finding 2)
# 3. (your finding 3)
#
# ## Recommendation
# (your recommendation)
#
# ## Limitation
# (your limitation)
#
# ## Tools
# Python · Pandas · Seaborn · Google Colab
#
# ## How to run
# Open the notebook in Google Colab and run all cells.
# ```
#
# ---
#
# ## Marking guide (100 points)
#
# | Task | Points |
# |------|--------|
# | 1 — Get to know the data | 10 |
# | 2 — Build the key measure | 10 |
# | 3 — Filtering questions | 15 |
# | 4 — The five client questions | 30 |
# | 5 — Top and bottom | 10 |
# | 6 — Use `.agg()` | 10 |
# | 7 — Report to your client | 15 |
#
# *(Task 8 is required. No repo = the assignment is not submitted.)*
#
# ---
#
# **A note from Ali:**
# Task 7 is worth 15 points and takes 5 minutes — but it is the part that separates a
# student from an analyst. Code that produces a number is easy. Telling someone what
# to *do* about that number is the job. 🚀
