# %% [markdown]
# # Week 5 — Day 2: Practice Lab
# ### Filtering, Sorting & Grouping
#
# ---
#
# **How to use this notebook**
# - Run the setup cell first.
# - Replace every `# YOUR CODE HERE` with your own code.
# - Check your answer against the expected result where one is given.
# - If a task fails, read the error out loud. Errors are instructions, not insults.
#
# This lab is the one that matters most in Week 5. Filtering and grouping are what you
# will use every single day for the rest of the course.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

titanic = sns.load_dataset("titanic")
tips = sns.load_dataset("tips")

print("titanic:", titanic.shape)
print("tips   :", tips.shape)
tips.head(3)

# %% [markdown]
# ## Part A — `.loc` and `.iloc`
#
# ### Task A1
# Show the row at **position 10** of `titanic` using `.iloc`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task A2
# Show rows at positions 5, 6, 7 using `.iloc` with a slice.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task A3
# Show rows with labels 5 to 7 using `.loc` with a slice.
# **How many rows did you get?** Compare with A2 and explain why in the cell below.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Why the difference:**
#
# *(write here)*

# %% [markdown]
# ### Task A4
# Using `.loc`, show rows 0 to 5 but **only** the columns `sex`, `age`, and `fare`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task A5
# Print the `fare` paid by the passenger at position 3. Use `.iloc`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part B — Boolean filtering
#
# ### Task B1
# Create a mask (a True/False Series) for passengers whose `fare` is more than 100.
# Print the mask's first 10 values, and print how many `True` values it has.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B2
# Use that mask to filter `titanic`. Show the first 5 rows of the result,
# displaying only `fare`, `class`, and `survived`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B3
# Filter `titanic` for **children** (`who` equals `"child"`).
# Print how many there were, and their survival rate.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B4
# Filter for passengers who were travelling **alone** (`alone` is `True`).
# Print the count and their average fare.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B5 — AND
# Find all passengers who were in **Third class AND under 18**.
# Print how many, and their survival rate.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B6 — OR
# Find all passengers who were either **under 10** or **over 60**.
# Print how many.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B7 — NOT
# Using `~`, find all passengers who were **not** travelling alone.
# Print how many.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B8 — three conditions
# Find male passengers, in First class, who survived.
# Print how many, and show their `age` and `fare` for the first 5.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B9 — `.isin()`
# Using `.isin()`, find all passengers who boarded from port `"C"` or `"Q"`
# (the `embarked` column). Print how many.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B10 — `.between()`
# Using `.between()`, find all passengers aged 20 to 40 inclusive.
# Print how many, and their average fare.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B11 — filter then compare
# Compute and print the survival rate for each of these three groups separately:
# - passengers in First class
# - passengers in Second class
# - passengers in Third class
#
# Use filtering (not groupby — that comes in Part E).

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part C — Sorting
#
# ### Task C1
# Show the 10 oldest passengers, displaying only `age`, `sex`, `class`, `survived`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C2
# Using `.nlargest()`, show the 3 most expensive tickets with their `class` and `sex`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C3
# Using `.nsmallest()`, show the 3 youngest passengers.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C4
# Sort `titanic` by `class` (ascending) and then by `age` (descending).
# Show the first 8 rows with `class`, `age`, `sex`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C5 — combine filter + sort
# Among **female survivors only**, show the 5 who paid the highest fares.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part D — Columns
#
# ### Task D1
# Make a copy of `titanic` called `df`.
# Add a column `family_size` = `sibsp` + `parch` + 1.
# Show `sibsp`, `parch`, `family_size` for the first 5 rows.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task D2
# Add a column to `df` called `fare_rounded` that is `fare` rounded to 0 decimals.
# Hint: `.round(0)` works on a whole column.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task D3
# Rename the column `fare` to `ticket_price` in `df`. Print the column list to confirm.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task D4
# Drop the columns `deck`, `alive`, and `adult_male` from `df`.
# Print the shape before and after.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task D5
# Using `df`, find the average `family_size` of passengers who survived
# versus those who did not. Use filtering.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part E — `groupby`
#
# ### Task E1
# Redo Task B11 (survival rate per class) in **one line** using `groupby`.
# Compare your answer to B11 — they should match.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E2
# Find the average `age` of each `class` using groupby.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E3
# Find how many passengers boarded from each port (`embarked`) using groupby and `.count()`.
# Then get the same answer using `value_counts()`. Do they match?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E4
# Find the average `fare` for each combination of `sex` and `class`.
# Group by two columns.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E5
# Using `.agg()`, for each `class` show the `count`, `mean`, `min`, and `max` of `age`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E6
# Using `.agg()` with a dictionary, for each `who` group show:
# - the mean `survived`
# - the mean `fare`
# - the max `age`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E7 — filter, then group
# Among **Third class passengers only**, find the survival rate by `sex`.
# (Filter first, then groupby.)

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part F — A different dataset: `tips`
#
# The `tips` dataset holds restaurant bills: total bill, tip amount, day, time, party size.
# Same tools, new data. This is what real work feels like.

# %%
tips.head()

# %% [markdown]
# ### Task F1
# Run the 5-command ritual on `tips` (head, shape, info, describe, isna sum).

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task F2
# Find all bills over $40. How many are there?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task F3
# Find the average tip on `Sun` compared to `Sat`. Use filtering.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task F4
# Using groupby, find the average `tip` for each `day`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task F5
# Add a column `tip_percent` = (`tip` / `total_bill`) * 100.
# Then find the average `tip_percent` for each `time` (Lunch vs Dinner).
# Remember to `.copy()` first.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task F6
# Show the 5 bills with the highest `tip_percent`. What do you notice about the `total_bill`
# on those rows? Write one sentence below.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Your observation:**
#
# *(write here)*

# %% [markdown]
# ## Stretch tasks (optional)
#
# ### Stretch 1
# Find the survival rate for every combination of `sex`, `class`, **and** `alone`.
# Group by three columns.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Stretch 2
# In `tips`, find the average `tip_percent` for each combination of `day` and `time`.
# Which combination tips best?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Stretch 3
# Among Titanic passengers with a **known age**, find the survival rate of each of
# these three age bands using filtering:
# - children (under 13)
# - teenagers (13 to 19)
# - adults (20 and over)
#
# Print all three with clear labels.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Stretch 4
# Try running this and read the error carefully:
# ```python
# titanic[(titanic["sex"] == "female") and (titanic["survived"] == 1)]
# ```
# Then write below, in your own words, why it fails.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Why it fails:**
#
# *(write here)*

# %% [markdown]
# ---
#
# ## Done!
#
# If you finished Part E comfortably, you can now answer almost any question about a
# table of data. That is a genuinely valuable skill.
#
# **Next:** Day 3 — we take these tools and build a real project for your GitHub. 🚀
