# %% [markdown]
# # Week 5 — Day 1: Practice Lab
# ### Series, DataFrames & Exploring a Dataset
#
# ---
#
# **How to use this notebook**
# - Run the setup cell first.
# - Each task has a `# YOUR CODE HERE` stub. Replace it with your code.
# - Run each cell and check the output against the expected result.
# - Stuck? Look back at the class notebook. Then ask in the WhatsApp group.
#
# There are no marks here. This is where you build muscle memory.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

titanic = sns.load_dataset("titanic")
print("Setup complete. Titanic shape:", titanic.shape)

# %% [markdown]
# ## Part A — Series
#
# ### Task A1
# Create a Series called `temps` from the list `[31, 35, 29, 40, 38]`.
# Print it.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task A2
# Create a Series called `city_temps` with the same values, but use these labels as the index:
# `["Karachi", "Lahore", "Islamabad", "Multan", "Sukkur"]`
#
# Then print it.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task A3
# From `city_temps`, print:
# - Lahore's temperature (using the label)
# - the first temperature (using `.iloc`)
# - the values of Karachi and Multan together

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task A4
# Create a Series called `prices` from this dictionary:
# `{"tea": 50, "coffee": 120, "juice": 80}`
#
# Then print the prices after a 10 rupee increase on everything.
# (Do not use a loop — Pandas does it in one line.)

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task A5
# Print the `.index`, `.values`, and `.dtype` of `city_temps`, each on its own line with a label.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part B — Build a DataFrame
#
# ### Task B1
# Create a DataFrame called `books` from this data:
#
# | title | author | year | pages |
# |-------|--------|------|-------|
# | Sapiens | Harari | 2011 | 443 |
# | Atomic Habits | Clear | 2018 | 320 |
# | Deep Work | Newport | 2016 | 296 |
# | Ikigai | Garcia | 2016 | 208 |
#
# Display it.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B2
# For `books`, print:
# - the shape
# - the column names
# - the data type of each column

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task B3
# Run `.info()` on `books`. Then in the markdown cell below, write one sentence
# about what `.info()` tells you that `.shape` does not.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Your answer:**
#
# *(write here)*

# %% [markdown]
# ### Task B4
# Print the average number of pages in `books`, and the page count of the longest book.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part C — The 5-command ritual on Titanic
#
# ### Task C1
# Show the first 7 rows of `titanic`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C2
# Show 4 **random** rows of `titanic`.
# Run the cell twice. Do you get the same rows?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C3
# Print how many rows and how many columns `titanic` has, in a friendly sentence like:
# `This dataset has 891 passengers and 15 columns.`
#
# Use `.shape` — do not type the numbers by hand.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task C4
# Run `.describe()` on `titanic`. Then answer in the markdown cell below:
# - What is the average fare?
# - What is the maximum age?

# %%
# YOUR CODE HERE

# %% [markdown]
# **Your answers:**
#
# - Average fare:
# - Maximum age:

# %% [markdown]
# ### Task C5
# Count the missing values in each column of `titanic`.
# Then write below which column has the **most** missing values.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Column with most missing values:**
#
# *(write here)*

# %% [markdown]
# ## Part D — Selecting columns
#
# ### Task D1
# Select just the `fare` column and show its first 5 values.
# Then print its `type()` — is it a Series or a DataFrame?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task D2
# Select the columns `sex`, `age`, and `survived` together and show the first 5 rows.
# Print the `type()` of the result too.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task D3
# Select **only** the `who` column but make the result a **DataFrame**, not a Series.
# Show the first 3 rows and print the type to prove it.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Part E — Quick summaries
#
# ### Task E1
# Print the average, minimum, and maximum `fare` — each on its own line with a label.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E2
# Print the survival rate of all passengers using `.mean()` on the `survived` column.
# Round it to 3 decimal places using `round()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E3
# How many passengers were in each `class`? Use `value_counts()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E4
# Show the **percentage** of passengers in each `class` (not the count).

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E5
# Print the unique values in the `who` column, and how many unique values there are.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Task E6
# Use `value_counts()` on the `embarked` column.
# Then, in the markdown cell below, write which port most passengers boarded from.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Most common port:**
#
# *(write here)*

# %% [markdown]
# ## Stretch tasks (optional — for those who finish early)
#
# ### Stretch 1
# Load the `penguins` dataset with `sns.load_dataset("penguins")`.
# Run the full 5-command ritual on it. Write 2 sentences describing what this dataset contains.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Stretch 2
# Create a new column in `books` called `pages_per_year`, which is `pages` divided by `year`.
# (This is a meaningless number — the point is just to practice creating a column.)
# Display `books` afterwards.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Stretch 3
# Without using `value_counts()`, find the survival rate of the Titanic as a **percentage**
# formatted like `38.4%`. Hint: `.mean()`, multiply by 100, and use an f-string with `:.1f`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Done!
#
# You now know how to open any dataset and understand it in under a minute.
# That is a real skill — most beginners jump straight to code and get lost.
#
# **Next:** Day 2 — filtering, sorting, and grouping. This is where Pandas gets powerful. 🚀
