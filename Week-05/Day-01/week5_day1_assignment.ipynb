# %% [markdown]
# # Week 5 — Day 1: Assignment
# ## Dataset Detective Report
#
# ### Code to AI — Python & Data Science (from Zero to Portfolio)
#
# ---
#
# **Your name:**
# **Date:**
#
# ---
#
# ## The task
#
# You are handed a dataset you have never seen before. Your job is to **investigate it**
# and write a short report on what it contains — using only the Pandas tools from Day 1.
#
# The dataset is **`penguins`** — real measurements of penguins from three islands in Antarctica.
#
# ## What to submit
# 1. Complete every task in this notebook.
# 2. Push this notebook to a **public GitHub repo** named `titanic-pandas-basics` (or your own clear name).
# 3. Add a `README.md` (template at the bottom of this notebook).
# 4. Post the repo link in the WhatsApp group.
#
# **Deadline:** before the next class.
#
# ## Rules
# - Use only what we covered on Day 1. No filtering or groupby yet — that is Day 2.
# - Every answer must be **computed by code**, not typed by hand.
# - Write your written answers in the markdown cells provided.
# - Keep it in English — reviewers on GitHub need to read it.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

penguins = sns.load_dataset("penguins")
print("Dataset loaded.")

# %% [markdown]
# ## Task 1 — First contact (10 points)
#
# Run the full **5-command ritual** on `penguins`. Use a separate cell for each step
# so the output is easy to read.
#
# ### 1a. `.head()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1b. `.shape` — print it as a sentence

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1c. `.info()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1d. `.describe()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 1e. `.isna().sum()`

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 2 — Describe the dataset in words (10 points)
#
# Using **only** the outputs above, fill in this table.
# Do not guess — read it off your own output.
#
# | Question | Your answer |
# |----------|-------------|
# | How many penguins (rows)? | |
# | How many columns? | |
# | Which columns are text? | |
# | Which columns are numbers? | |
# | Which column has the most missing values? | |
# | How many missing values does it have? | |
#
# Then write **2 to 3 sentences** in plain English explaining what this dataset is about,
# as if telling a friend who has never seen it.
#
# **Your description:**
#
# *(write here)*

# %% [markdown]
# ## Task 3 — Column selection (10 points)
#
# ### 3a. Select only the `species` column. Print its type and its first 5 values.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3b. Create a smaller DataFrame called `body_data` containing only these three columns:
# `bill_length_mm`, `flipper_length_mm`, `body_mass_g`.
#
# Show its first 5 rows and print its shape.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 3c. Run `.describe()` on `body_data` only.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 4 — The numbers (15 points)
#
# Compute and print each of these with a clear label:
#
# 1. The average body mass (in grams)
# 2. The heaviest penguin's body mass
# 3. The lightest penguin's body mass
# 4. The median flipper length
# 5. The average bill length, rounded to 2 decimal places

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Task 5 — The categories (15 points)
#
# ### 5a. How many penguins of each `species`? Use `value_counts()`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 5b. What **percentage** of penguins live on each `island`?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### 5c. Print the unique values of `sex`, and how many unique values there are.
#
# Look carefully at the output. Is there anything surprising? Write your observation below.

# %%
# YOUR CODE HERE

# %% [markdown]
# **Your observation:**
#
# *(write here)*

# %% [markdown]
# ## Task 6 — Your findings (20 points)
#
# Write **three findings** about this dataset. A finding is one sentence that states
# something true and interesting, backed by a number you computed above.
#
# Good example: *"Adelie is the most common species, making up 44% of all penguins in the dataset."*
# Weak example: *"There are penguins in the dataset."*
#
# **Finding 1:**
#
# **Finding 2:**
#
# **Finding 3:**

# %% [markdown]
# ## Task 7 — One question you cannot answer yet (10 points)
#
# Write down **one question** about this dataset that you would like to answer,
# but cannot with Day 1 tools alone.
#
# Example: *"Do Gentoo penguins weigh more than Adelie penguins on average?"*
#
# Then, in one sentence, say what tool you think you would need.
# (You will learn it on Day 2 — this is just to make you think.)
#
# **Your question:**
#
# **What you would need:**

# %% [markdown]
# ## Task 8 — Ship it to GitHub (10 points)
#
# 1. Create a new **public** repo on GitHub.
# 2. Upload this completed notebook.
# 3. Add a `README.md` using the template below.
# 4. Post your repo link in the WhatsApp group.
#
# ### README template — copy this into your `README.md`
#
# ```markdown
# # Penguins Dataset Exploration
#
# A first exploration of the Palmer Penguins dataset using Pandas.
# Part of the Code to AI course (Week 5, Day 1).
#
# ## The dataset
# Body measurements of 344 penguins from three islands in Antarctica.
# Loaded via `seaborn.load_dataset("penguins")`.
#
# ## What I did
# - Ran a full first-look inspection (head, shape, info, describe, missing values)
# - Selected and summarized the numeric measurement columns
# - Counted the categories: species, island, sex
#
# ## Key findings
# 1. (your finding 1)
# 2. (your finding 2)
# 3. (your finding 3)
#
# ## Tools
# Python · Pandas · Seaborn · Google Colab
#
# ## How to run
# Open `week5_day1_assignment.ipynb` in Google Colab and run all cells.
# ```
#
# ---
#
# ## Marking guide (100 points)
#
# | Task | Points |
# |------|--------|
# | 1 — The 5-command ritual | 10 |
# | 2 — Describe the dataset | 10 |
# | 3 — Column selection | 10 |
# | 4 — The numbers | 15 |
# | 5 — The categories | 15 |
# | 6 — Your findings | 20 |
# | 7 — Your open question | 10 |
# | 8 — GitHub + README | 10 |
#
# ---
#
# **A note from Ali:**
# Do not rush the writing parts. Anyone can call `.describe()`. What makes you a data
# person is being able to *say what it means*. That is the skill US reviewers look for
# in your repo. 🚀
